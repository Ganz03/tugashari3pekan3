# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2>Soal 1: Multiple Subplots</h2>
#
# Dengan data di bawah ini buatlah visualisasi seperti expected output:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(2*-np.pi, 2*np.pi, 200)

tan = np.tan(x)/10
cos = np.cos(x)
sin = np.sin(x)

# %%
#code here
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(2 * -np.pi, 2 * np.pi, 200)
tan = np.tan(x) / 10
cos = np.cos(x)
sin = np.sin(x)

plt.figure(figsize=(10, 6)) 

plt.plot(x, tan, label='tan(x)/10', color='b')
plt.plot(x, cos, label='cos(x)', color='g')
plt.plot(x, sin, label='sin(x)', color='r')

plt.title('Plot of Trigonometric Functions')
plt.xlabel('x')
plt.ylabel('Function Value')

plt.legend()

plt.grid(True) 
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\argana\Downloads\Tugas Hari 3 Pekan 3.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #code here
# ----> <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> x = np.linspace(2 * -np.pi, 2 * np.pi, 200)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xdrkV37TJk7isPQIjg9gNJ6capaCLYam)

# %% [markdown]
# <h2>Soal 2: Nested Axis</h2>
#
# Dengan data di bawah ini, buatlah visualisasi seperti expected output:

# %%
x = np.linspace(2*-np.pi, 2*np.pi, 100)
y = np.cos(x)
y2 = np.cos(x**2)
y3 = np.cos(x**3)
y4 = np.cos(x**4)
y5 = np.cos(x**5)

# %%
#code here
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(2 * -np.pi, 2 * np.pi, 100)
y = np.cos(x)
y2 = np.cos(x ** 2)
y3 = np.cos(x ** 3)
y4 = np.cos(x ** 4)
y5 = np.cos(x ** 5)

plt.figure(figsize=(12, 8))  
i
plt.plot(x, y, label='cos(x)', color='b')
plt.plot(x, y2, label='cos(x^2)', color='g')
plt.plot(x, y3, label='cos(x^3)', color='r')
plt.plot(x, y4, label='cos(x^4)', color='c')
plt.plot(x, y5, label='cos(x^5)', color='m')

plt.title('Plot of Various Cosine Functions')
plt.xlabel('x')
plt.ylabel('Function Value')

plt.legend()

plt.grid(True)  # Menampilkan grid
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\argana\Downloads\Tugas Hari 3 Pekan 3.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> #code here
# ----> <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/argana/Downloads/Tugas%20Hari%203%20Pekan%203.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> x = np.linspace(2 * -np.pi, 2 * np.pi, 100)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xIdrYVaafiMdAP59fyMkxZ-qwxapAD_g)
